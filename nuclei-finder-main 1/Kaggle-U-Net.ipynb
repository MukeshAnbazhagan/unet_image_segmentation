# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'C:/Users/Laasya Reddy/Datasets (2)/Datasets/stage1_train/'
TEST_PATH = 'C:/Users/Laasya Reddy/Datasets (2)/Datasets/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# C:\Users\Laasya Reddy\AppData\Local\Temp\ipykernel_10696\2425402591.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                                                          | 0/461 [00:00<?, ?it/s]C:\Users\Laasya Reddy\AppData\Local\Temp\ipykernel_10696\2425402591.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|████████████████████████████████████████████████████████████████████████████████| 461/461 [05:54<00:00,  1.30it/s]
# Getting and resizing test images ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 65/65 [00:01<00:00, 33.78it/s]
# Done!

# %%
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.cast((y_pred>t),tf.int32)
        score, up_opt = tf.keras.metrics.IoU(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[tf.keras.metrics.IoU(num_classes=2, target_class_ids=[0])])
model.summary()
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda_21 (Lambda)             (None, 128, 128, 3)  0           ['input_22[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 128, 128, 16  448         ['lambda_21[0][0]']
#                                 )
#
#  dropout_185 (Dropout)          (None, 128, 128, 16  0           ['conv2d_390[0][0]']
#                                 )
#
#  conv2d_391 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_185[0][0]']
#                                 )
#
#  max_pooling2d_84 (MaxPooling2D  (None, 64, 64, 16)  0           ['conv2d_391[0][0]']
#  )
#
#  conv2d_392 (Conv2D)            (None, 64, 64, 32)   4640        ['max_pooling2d_84[0][0]']
#
#  dropout_186 (Dropout)          (None, 64, 64, 32)   0           ['conv2d_392[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_186[0][0]']
#
#  max_pooling2d_85 (MaxPooling2D  (None, 32, 32, 32)  0           ['conv2d_393[0][0]']
#  )
#
#  conv2d_394 (Conv2D)            (None, 32, 32, 64)   18496       ['max_pooling2d_85[0][0]']
#
#  dropout_187 (Dropout)          (None, 32, 32, 64)   0           ['conv2d_394[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_187[0][0]']
#
#  max_pooling2d_86 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_395[0][0]']
#  )
#
#  conv2d_396 (Conv2D)            (None, 16, 16, 128)  73856       ['max_pooling2d_86[0][0]']
#
#  dropout_188 (Dropout)          (None, 16, 16, 128)  0           ['conv2d_396[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_188[0][0]']
#
#  max_pooling2d_87 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_397[0][0]']
#  )
#
#  conv2d_398 (Conv2D)            (None, 8, 8, 256)    295168      ['max_pooling2d_87[0][0]']
#
#  dropout_189 (Dropout)          (None, 8, 8, 256)    0           ['conv2d_398[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 8, 8, 256)    590080      ['dropout_189[0][0]']
#
#  conv2d_transpose_81 (Conv2DTra  (None, 16, 16, 128)  131200     ['conv2d_399[0][0]']
#  nspose)
#
#  concatenate_80 (Concatenate)   (None, 16, 16, 256)  0           ['conv2d_transpose_81[0][0]',
#                                                                   'conv2d_397[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 16, 16, 128)  295040      ['concatenate_80[0][0]']
#
#  dropout_190 (Dropout)          (None, 16, 16, 128)  0           ['conv2d_400[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_190[0][0]']
#
#  conv2d_transpose_82 (Conv2DTra  (None, 32, 32, 64)  32832       ['conv2d_401[0][0]']
#  nspose)
#
#  concatenate_81 (Concatenate)   (None, 32, 32, 128)  0           ['conv2d_transpose_82[0][0]',
#                                                                   'conv2d_395[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 32, 32, 64)   73792       ['concatenate_81[0][0]']
#
#  dropout_191 (Dropout)          (None, 32, 32, 64)   0           ['conv2d_402[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_191[0][0]']
#
#  conv2d_transpose_83 (Conv2DTra  (None, 64, 64, 32)  8224        ['conv2d_403[0][0]']
#  nspose)
#
#  concatenate_82 (Concatenate)   (None, 64, 64, 64)   0           ['conv2d_transpose_83[0][0]',
#                                                                   'conv2d_393[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 64, 64, 32)   18464       ['concatenate_82[0][0]']
#
#  dropout_192 (Dropout)          (None, 64, 64, 32)   0           ['conv2d_404[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_192[0][0]']
#
#  conv2d_transpose_84 (Conv2DTra  (None, 128, 128, 16  2064       ['conv2d_405[0][0]']
#  nspose)                        )
#
#  concatenate_83 (Concatenate)   (None, 128, 128, 32  0           ['conv2d_transpose_84[0][0]',
#                                 )                                 'conv2d_391[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 128, 128, 16  4624        ['concatenate_83[0][0]']
#                                 )
#
#  dropout_193 (Dropout)          (None, 128, 128, 16  0           ['conv2d_406[0][0]']
#                                 )
#
#  conv2d_407 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_193[0][0]']
#                                 )
#
#  conv2d_408 (Conv2D)            (None, 128, 128, 1)  17          ['conv2d_407[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4907 - io_u_1: 0.7472
# Epoch 1: val_loss improved from inf to 0.24090, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 1s/step - loss: 0.4907 - io_u_1: 0.7472 - val_loss: 0.2409 - val_io_u_1: 0.7834
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2758 - io_u_1: 0.7472
# Epoch 2: val_loss improved from 0.24090 to 0.18678, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 41s 2s/step - loss: 0.2758 - io_u_1: 0.7472 - val_loss: 0.1868 - val_io_u_1: 0.7834
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2088 - io_u_1: 0.7472
# Epoch 3: val_loss improved from 0.18678 to 0.14318, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 2s/step - loss: 0.2088 - io_u_1: 0.7472 - val_loss: 0.1432 - val_io_u_1: 0.7834
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1810 - io_u_1: 0.7472
# Epoch 4: val_loss improved from 0.14318 to 0.12571, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 48s 2s/step - loss: 0.1810 - io_u_1: 0.7472 - val_loss: 0.1257 - val_io_u_1: 0.7834
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1621 - io_u_1: 0.7472
# Epoch 5: val_loss did not improve from 0.12571
# 26/26 [==============================] - 43s 2s/step - loss: 0.1621 - io_u_1: 0.7472 - val_loss: 0.1291 - val_io_u_1: 0.7834
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1441 - io_u_1: 0.7472
# Epoch 6: val_loss improved from 0.12571 to 0.10611, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 2s/step - loss: 0.1441 - io_u_1: 0.7472 - val_loss: 0.1061 - val_io_u_1: 0.7834
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1414 - io_u_1: 0.7472
# Epoch 7: val_loss did not improve from 0.10611
# 26/26 [==============================] - 42s 2s/step - loss: 0.1414 - io_u_1: 0.7472 - val_loss: 0.1062 - val_io_u_1: 0.7834
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1346 - io_u_1: 0.7472
# Epoch 8: val_loss improved from 0.10611 to 0.09867, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 44s 2s/step - loss: 0.1346 - io_u_1: 0.7472 - val_loss: 0.0987 - val_io_u_1: 0.7834
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1292 - io_u_1: 0.7472
# Epoch 9: val_loss did not improve from 0.09867
# 26/26 [==============================] - 43s 2s/step - loss: 0.1292 - io_u_1: 0.7472 - val_loss: 0.1093 - val_io_u_1: 0.7834
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1212 - io_u_1: 0.7472
# Epoch 10: val_loss improved from 0.09867 to 0.09795, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 2s/step - loss: 0.1212 - io_u_1: 0.7472 - val_loss: 0.0980 - val_io_u_1: 0.7834
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1149 - io_u_1: 0.7472
# Epoch 11: val_loss improved from 0.09795 to 0.09537, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 44s 2s/step - loss: 0.1149 - io_u_1: 0.7472 - val_loss: 0.0954 - val_io_u_1: 0.7834
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1126 - io_u_1: 0.7472
# Epoch 12: val_loss did not improve from 0.09537
# 26/26 [==============================] - 43s 2s/step - loss: 0.1126 - io_u_1: 0.7472 - val_loss: 0.0989 - val_io_u_1: 0.7834
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1122 - io_u_1: 0.7472
# Epoch 13: val_loss improved from 0.09537 to 0.08974, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 2s/step - loss: 0.1122 - io_u_1: 0.7472 - val_loss: 0.0897 - val_io_u_1: 0.7834
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1051 - io_u_1: 0.7472
# Epoch 14: val_loss improved from 0.08974 to 0.08842, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 44s 2s/step - loss: 0.1051 - io_u_1: 0.7472 - val_loss: 0.0884 - val_io_u_1: 0.7834
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1078 - io_u_1: 0.7472
# Epoch 15: val_loss did not improve from 0.08842
# 26/26 [==============================] - 43s 2s/step - loss: 0.1078 - io_u_1: 0.7472 - val_loss: 0.0899 - val_io_u_1: 0.7834
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1061 - io_u_1: 0.7472
# Epoch 16: val_loss improved from 0.08842 to 0.08328, saving model to model-dsbowl2018-1.h5
# 26/26 [==============================] - 43s 2s/step - loss: 0.1061 - io_u_1: 0.7472 - val_loss: 0.0833 - val_io_u_1: 0.7834
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1025 - io_u_1: 0.7472
# Epoch 17: val_loss did not improve from 0.08328
# 26/26 [==============================] - 48s 2s/step - loss: 0.1025 - io_u_1: 0.7472 - val_loss: 0.0858 - val_io_u_1: 0.7834
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0997 - io_u_1: 0.7472
# Epoch 18: val_loss did not improve from 0.08328
# 26/26 [==============================] - 43s 2s/step - loss: 0.0997 - io_u_1: 0.7472 - val_loss: 0.0839 - val_io_u_1: 0.7834
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1068 - io_u_1: 0.7472
# Epoch 19: val_loss did not improve from 0.08328
# 26/26 [==============================] - 43s 2s/step - loss: 0.1068 - io_u_1: 0.7472 - val_loss: 0.0937 - val_io_u_1: 0.7834
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1045 - io_u_1: 0.7472
# Epoch 20: val_loss did not improve from 0.08328
# 26/26 [==============================] - 44s 2s/step - loss: 0.1045 - io_u_1: 0.7472 - val_loss: 0.0850 - val_io_u_1: 0.7834
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1000 - io_u_1: 0.7472
# Epoch 21: val_loss did not improve from 0.08328
# 26/26 [==============================] - 43s 2s/step - loss: 0.1000 - io_u_1: 0.7472 - val_loss: 0.0915 - val_io_u_1: 0.7834
# Epoch 21: early stopping

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 13/13 [==============================] - 7s 461ms/step
# 2/2 [==============================] - 1s 236ms/step
# 3/3 [==============================] - 1s 225ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %%
iou = results.history['io_u_1']
iou_val = results.history['val_io_u_1']
epochs = range(1,22)
plt.plot(epochs, iou, 'g', label='iou')
plt.plot(epochs, iou_val, 'b', label='val_iou')
plt.title('Plot Between Epochs and iou value')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
